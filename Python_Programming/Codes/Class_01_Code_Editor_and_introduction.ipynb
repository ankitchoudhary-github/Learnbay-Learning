# %%
.py - file
.ipynb - Interactive Python Notebook

# %% [markdown]
# # Heading 1
# ## Heading 2
# # ...
# ###### Heading 6
#
# This is **Normal** Text

# %%
a = 10

# %%
print(a)
# Out:
# 20

# %%
a = 20
