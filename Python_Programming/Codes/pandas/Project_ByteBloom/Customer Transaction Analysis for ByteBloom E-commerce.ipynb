# %% [markdown]
# # **Project: Customer Transaction Analysis for ByteBloom E-commerce**
#
# Welcome to the ByteBloom E-commerce data analysis project! This case study is designed to simulate a real-world data analysis task from start to finish. You'll take on the role of a data analyst at an online retail company, tasked with uncovering insights from raw, messy customer transaction data.
#
# ---
#
# ## **1. Domain Explanation: The World of E-commerce & Retail**
#
# Before diving into the data, it's crucial to understand the business context. The e-commerce and retail sector is a dynamic and highly competitive industry where data is the key to success.
#
# ### **The Business Model: How E-commerce Works**
#
# Modern e-commerce companies are complex operations that go far beyond just having a website. Their business model revolves around a few core pillars:
#
# 1.  **Inventory & Supply Chain:** A company must decide how to source its products. Some hold their own inventory in warehouses, giving them control over stock and shipping (like ByteBloom). Others use a **dropshipping** model, where they pass orders directly to a third-party manufacturer who then ships to the customer. The supply chain involves everything from procuring products from suppliers, managing warehouse stock, to logistics for order fulfillment and delivery. An efficient supply chain is critical for ensuring products are available (**in-stock**) and delivered to customers quickly.
#
# 2.  **Marketing & Sales:** Unlike a physical store, an e-commerce business must actively drive traffic to its website. This is done through a multi-channel marketing strategy, including **Search Engine Optimization (SEO)** to rank high on Google, **Search Engine Marketing (SEM)** through paid ads, social media campaigns, email marketing, and influencer partnerships. The goal of these efforts is to attract potential customers and guide them through a sales funnel, from awareness to final purchase.
#
# 3.  **Customer Service:** In a digital marketplace, trust is paramount. Excellent customer service builds that trust. This includes providing support for product inquiries, managing order issues, and handling returns and refunds smoothly. A positive customer service experience is often the deciding factor in whether a first-time buyer becomes a loyal, repeat customer.
#
# ### **The Importance of Data**
#
# In e-commerce, customer transaction data is the **lifeblood** of the business. Every single purchase, click, and interaction creates a data point. This data is not just a record of sales; it's a direct reflection of customer behavior, preferences, and needs. By analyzing this data, a company can move from making decisions based on guesswork to making them based on evidence. Transaction data can reveal which products are popular, who the most valuable customers are, when customers are most likely to buy, and which marketing strategies are actually working. Without analyzing this data, a business is flying blind.
#
# ### **Key Performance Indicators (KPIs)**
#
# To measure success and health, e-commerce businesses rely on several critical KPIs:
#
# * **Customer Lifetime Value (CLV):** This metric predicts the total net profit a company can expect to make from a single customer over the entire duration of their relationship. A high CLV indicates strong customer loyalty and profitability. Businesses use CLV to justify spending more to acquire high-value customers.
# * **Average Order Value (AOV):** AOV measures the average dollar amount a customer spends per transaction. Increasing AOV is a key goal, often pursued through strategies like product bundling, upselling, and offering free shipping for orders above a certain threshold.
# * **Customer Acquisition Cost (CAC):** CAC is the total cost of sales and marketing efforts required to acquire a new customer. It's crucial to ensure that a customer's lifetime value (CLV) is significantly higher than the cost to acquire them (CAC).
# * **Churn Rate:** This measures the percentage of customers who stop doing business with a company over a given period. A high churn rate is a major red flag, as it's far more expensive to acquire a new customer than to retain an existing one. Analyzing the behavior of churned customers can reveal pain points in the customer experience.
# * **Conversion Rate:** This is the percentage of website visitors who complete a desired action, usually making a purchase. A low conversion rate might indicate issues with the website's design, product pricing, or checkout process.
#
# ### **Common Challenges & The Role of Data Analysis**
#
# E-commerce companies face persistent challenges that data analysis can directly address:
#
# * **Challenge: Cart Abandonment.** Many users add items to their cart but leave without completing the purchase.
#     * **Data Analysis Solution:** By analyzing where users drop off in the checkout process, companies can identify and fix friction points. They can also use data to trigger automated follow-up emails with reminders or special offers.
# * **Challenge: Customer Retention.** Keeping customers coming back is difficult in a competitive market.
#     * **Data Analysis Solution:** Analyzing purchasing history allows for the creation of targeted loyalty programs and personalized marketing campaigns that make customers feel valued. **RFM Analysis** (Recency, Frequency, Monetary) is a common technique to segment customers and identify the most loyal ones.
# * **Challenge: Inventory Management.** Holding too much stock (overstock) ties up capital, while holding too little (stockout) leads to lost sales.
#     * **Data Analysis Solution:** Sales data can be used to forecast future demand for specific products, helping the company optimize inventory levels, reduce waste, and ensure popular items are always available.
# * **Challenge: Personalization at Scale.** Customers now expect personalized recommendations and offers.
#     * **Data Analysis Solution:** By analyzing browsing history and past purchases, businesses can build sophisticated recommendation engines (like "Customers who bought this also bought...") that significantly improve the user experience and increase AOV.
#
# In summary, data analysis is not just a technical function but a core strategic driver in e-commerce, providing the actionable insights needed to grow revenue, improve efficiency, and build lasting customer relationships.
#
# ---
#
# ## **2. Project Description & Business Understanding**
#
# Now, let's focus on our fictional company, "ByteBloom," and the specific business problem you are tasked with solving.
#
# ### **Company Background: ByteBloom**
#
# **ByteBloom** is a mid-sized e-commerce retailer that has carved out a niche in the competitive consumer electronics market. Founded five years ago, the company specializes in selling high-quality, innovative gadgets, smart home devices, and unique tech accessories. They pride themselves on curating a unique product catalog that appeals to tech-savvy millennials and Gen Z consumers. While ByteBloom has experienced healthy growth in its initial years, it now faces stiff competition from retail giants like Amazon and specialized direct-to-consumer brands. Their primary sales channels are their website and mobile app. They operate their own warehouse and manage fulfillment in-house to maintain control over the customer experience.
#
# ### **The Business Problem**
#
# For the past two quarters, ByteBloom's impressive revenue growth has **stagnated**. The executive team is concerned. Initial reports suggest that while customer acquisition numbers are stable, customer **retention** appears to be declining. The marketing team's broad, one-size-fits-all campaigns are showing diminishing returns, and the cost to acquire new customers is rising. Management suspects that they don't understand their customers' evolving behaviors and needs deeply enough. They are asking a critical question: **How can we leverage our transaction data to create more targeted, effective strategies that will re-ignite growth and improve customer loyalty?**
#
# As a data analyst, you have been given a raw export of the company's transaction data. Your mission is to clean this data, analyze it, and extract actionable insights to present to the management.
#
# ### **Project Goals & Objectives**
#
# Your analysis should be guided by the following specific business objectives:
#
# 1.  **Identify Most Valuable Customer Segments:** Determine who the top customers are in terms of spending and frequency. What are their common characteristics?
# 2.  **Analyze Purchasing Patterns:** Uncover insights about product popularity, product associations (which items are bought together), and sales trends over time to help optimize inventory and marketing.
# 3.  **Determine Channel & Payment Effectiveness:** Analyze how purchasing behavior differs across devices (Desktop vs. Mobile). Are certain payment methods associated with higher-value orders?
# 4.  **Understand Churn Factors:** Identify characteristics or behaviors of customers who are inactive or have likely churned to inform future retention strategies.
#
# ### **The Data Analysis Lifecycle**
#
# To achieve these goals, you will follow a structured data analysis process:
#
# 1.  **Problem Definition:** We've already done this—understanding ByteBloom's business problem and setting clear objectives.
# 2.  **Data Collection:** You have been provided with a raw, imperfect dataset simulating a real-world data dump from a company's database.
# 3.  **Data Cleaning & Preprocessing:** This is a critical first step. You will tackle the messy dataset, fixing incorrect data types, handling missing values, removing duplicates, and standardizing inconsistent categorical data.
# 4.  **Feature Engineering:** You will create new, more informative columns from the existing data (e.g., calculating customer age from their date of birth) to enable deeper analysis.
# 5.  **Exploratory Data Analysis (EDA):** You will dive deep into the data using statistics and visualizations to identify patterns, trends, and relationships that address the business objectives.
# 6.  **Drawing Conclusions:** Finally, you will synthesize your findings into concrete, data-driven recommendations that ByteBloom's management can act upon.
#
# ---
#
# ## **3. Dataset Column Explanation**
#
# Here is a breakdown of the 30 columns in your dataset. Pay close attention to the potential issues you'll need to address.
#
# | Column Name | Description | Potential Cleaning Issues |
# | :--- | :--- | :--- |
# | **transaction_id** | A unique identifier for each individual transaction. | Should be unique. Check for any duplicates. |
# | **transaction_date** | The date the transaction occurred. | Should be parsed into a proper datetime format. |
# | **transaction_time** | The time the transaction occurred. | Should be parsed into a proper time/datetime format. |
# | **transaction_amount** | The total value of the transaction. | **String format** with `$` and commas. Must be converted to a numeric type (float). |
# | **currency** | The currency used for the transaction. | Check for consistency (e.g., all USD). |
# | **payment_method** | The method used for payment. | **Inconsistent naming** (e.g., "Credit Card", "credit_card", "CC"). Needs standardization. |
# | **transaction_status** | The status of the transaction. | Check for any non-standard values. |
# | **customer_id** | A unique identifier for each customer. | Check for any formatting issues. |
# | **customer_first_name** | The first name of the customer. | General text cleaning may be needed. |
# | **customer_last_name** | The last name of the customer. | General text cleaning may be needed. |
# | **customer_email** | The customer's email address. | Check for invalid formats. |
# | **customer_phone** | The customer's phone number. | **Inconsistent formats**. Needs parsing/standardization. |
# | **customer_dob** | The customer's date of birth. | **Missing values (NaN)**. Should be parsed to datetime. |
# | **customer_gender** | The gender of the customer. | **Missing values (NaN)** and may have inconsistent entries. |
# | **account_creation_date**| The date the customer created their account. | Should be parsed into a proper datetime format. |
# | **last_login_date** | The date of the customer's last login. | **Missing values (NaN)**. Should be parsed to datetime. |
# | **loyalty_program_member**| Indicates if the customer is in the loyalty program. | **Mixed types** (e.g., TRUE/FALSE, 1/0). Needs to be standardized to a boolean type. |
# | **product_id** | A unique identifier for each product. | Check for any formatting issues. |
# | **product_name** | The name of the product purchased. | General text cleaning. |
# | **product_category** | The main category of the product. | **Inconsistent capitalization and naming** (e.g., "Electronics", "electronics", "ELEC"). |
# | **product_subcategory** | The sub-category of the product. | General text cleaning. |
# | **quantity** | The number of units of the product purchased. | **Incorrect data type** (contains strings like 'N/A'). Must be converted to integer. |
# | **item_price** | The price per unit of the product. | **String format** with '$' and commas. Must be converted to a numeric type (float). |
# | **discount_applied_percent**| The discount percentage applied to the item. | Should be a numeric type. Check for outliers. |
# | **store_id** | Identifier for the store (can represent different online channels). | Check for consistency. |
# | **shipping_address_city** | The city where the order was shipped. | General text cleaning. |
# | **shipping_address_state** | The state or province where the order was shipped. | **Missing values (NaN)**. |
# | **shipping_address_country**| The country where the order was shipped. | **Inconsistent naming** (e.g., "USA", "United States", "U.S.A."). |
# | **device_used** | The device used to make the transaction. | Check for consistency and standardize if needed. |
# | **ip_address** | The IP address of the customer. | Check for invalid formats. |
#
# ---

# %% [markdown]
# ## **4. Analytical Questions**
#
# Use the following questions to guide your analysis. They are structured to take you from data cleaning all the way to strategic recommendations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

pd.set_option('display.max_columns', None)
# %matplotlib inline
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/_statistics.py:32: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 2.5.2)
#   from scipy.stats import gaussian_kde

# %% [markdown]
# ## **Load the dataset**

# %%
df = pd.read_csv('sample_data_customer_transaction_data.csv')
print('Shape:', df.shape)
df.head()
# Out:
# Shape: (1030, 30)
#                          transaction_id transaction_date transaction_time  \
# 0  b08a9d98-986e-41ec-989e-4acc5f43accb       2024-10-06         19:42:37
# 1  96f2f3b9-a3a5-493d-a09d-dc8875c6d704       2021-05-17         03:37:08
# 2  92a55669-dfe0-4edd-9770-2680c4aac6f6       2025-06-06         17:58:09
# 3  7dc592f6-c821-4318-8607-bf776147a910       2024-11-13         05:45:45
# 4  ad969b12-6f09-4a10-a911-90bc9f6953ad       2023-06-29         04:04:51
#
#   transaction_amount currency payment_method transaction_status  \
# 0            $885.57      USD     Debit Card             Failed
# 1            $906.74      USD     Debit Card           Refunded
# 2          $1,669.43      USD    credit_card           Refunded
# 3          $3,199.98      USD  Bank Transfer          Completed
# 4          $2,757.83      USD     Debit Card            Pending
#
#                             customer_id customer_first_name  \
# ...

# %% [markdown]
# ### **A. Data Cleaning and Preprocessing (Pandas & Core Python)**
#
# 1.  How many duplicate rows are there in the dataset? Write the code to remove them.

# %%
dup_count = df.duplicated().sum()
print('Duplicate rows:', dup_count)
df = df.drop_duplicates().reset_index(drop=True)
print('Shape after removing duplicates:', df.shape)
# Out:
# Duplicate rows: 30
# Shape after removing duplicates: (1000, 30)

# %% [markdown]
# 2.  Identify all columns that have missing values and calculate the percentage of missing values for each.

# %%
missing = df.isna().sum()
missing_pct = (df.isna().mean() * 100).round(2)
missing_df = pd.DataFrame({'Missing Count': missing, 'Missing %': missing_pct})
missing_df = missing_df[missing_df['Missing Count'] > 0].sort_values('Missing %', ascending=False)
missing_df
# Out:
#                         Missing Count  Missing %
# customer_dob                       77        7.7
# last_login_date                    73        7.3
# customer_gender                    71        7.1
# shipping_address_state             65        6.5
# quantity                           23        2.3

# %% [markdown]
# 3.  Devise a strategy to handle the missing values in `customer_dob` and `last_login_date`. Implement it.

# %%
# Handle missing customer_dob - fill with the median date of birth
dob_median = pd.to_datetime(df['customer_dob'].dropna()).median()
df['customer_dob'] = df['customer_dob'].fillna(dob_median)

# Handle missing last_login_date - fill with the account creation date
df['last_login_date'] = df['last_login_date'].fillna(df['account_creation_date'])

print('Remaining missing customer_dob:', df['customer_dob'].isna().sum())
print('Remaining missing last_login_date:', df['last_login_date'].isna().sum())
# Out:
# Remaining missing customer_dob: 0
# Remaining missing last_login_date: 0

# %% [markdown]
# 4.  The `transaction_amount` and `item_price` columns are strings. Convert them into a numeric format (float).

# %%
def to_float(s):
    if pd.isna(s):
        return np.nan
    return float(str(s).replace('$', '').replace(',', ''))

df['transaction_amount'] = df['transaction_amount'].apply(to_float)
df['item_price'] = df['item_price'].apply(to_float)

print('transaction_amount dtype:', df['transaction_amount'].dtype)
print('item_price dtype:', df['item_price'].dtype)
df[['transaction_amount', 'item_price']].head()
# Out:
# transaction_amount dtype: float64
# item_price dtype: float64
#    transaction_amount  item_price
# 0              885.57      125.88
# 1              906.74      384.05
# 2             1669.43      258.33
# 3             3199.98      477.48
# 4             2757.83      372.63

# %% [markdown]
# 5.  The `quantity` column has non-numeric values like 'N/A'. Identify these rows and replace the values with the median quantity of the dataset.

# %% [markdown]
# qty_median = df['quantity'].median()
# print('Median quantity:', qty_median)
# non_numeric = pd.to_numeric(df['quantity'], errors='coerce')
# df['quantity'] = non_numeric.fillna(qty_median).astype(int)
# print('Remaining non-numeric quantity:', df['quantity'].isna().sum())
# print('Any NaNs after:', df['quantity'].isna().any())

# %% [markdown]
# 6.  Clean the `product_category` column by standardizing all entries to a consistent format (e.g., Title Case).

# %%
cat_map = {
    'electronics': 'Electronics', 'ELEC': 'Electronics',
    'books': 'Books',
    'beauty': 'Beauty', 'BEAUTY': 'Beauty',
    'apparel': 'Apparel',
    'home goods': 'Home Goods',
}
df['product_category'] = df['product_category'].apply(
    lambda x: cat_map.get(str(x).strip(), str(x).strip().title()))
print(df['product_category'].unique())
# Out:
# ['Electronics' 'Beauty' 'Books' 'Home Goods' 'Apparel']

# %% [markdown]
# 7.  Standardize the `payment_method` column to have only three distinct values: 'Credit Card', 'PayPal', 'Bank Transfer'.

# %%
pay_map = {
    'credit_card': 'Credit Card', 'CC': 'Credit Card', 'Debit Card': 'Credit Card',
    'paypal': 'PayPal', 'Pay Pal': 'PayPal',
    'bank transfer': 'Bank Transfer', 'Bank_Transfer': 'Bank Transfer',
}
df['payment_method'] = df['payment_method'].apply(
    lambda x: pay_map.get(str(x).strip(), str(x).strip().title()))
print(df['payment_method'].unique())
# Out:
# ['Credit Card' 'Bank Transfer' 'PayPal' 'Paypal']

# %% [markdown]
# 8.  Parse the `customer_phone` numbers to a standard E.164 format (e.g., +1XXXXXXXXXX). (This is a complex core python/regex task).

# %%
def standardize_phone(phone):
    if pd.isna(phone):
        return np.nan
    digits = re.sub(r'\D', '', str(phone))
    if len(digits) == 10:
        digits = '1' + digits
    if len(digits) == 11 and digits.startswith('1'):
        return '+' + digits
    return '+' + digits

df['customer_phone_standard'] = df['customer_phone'].apply(standardize_phone)
df[['customer_phone', 'customer_phone_standard']].head(10)
# Out:
#          customer_phone customer_phone_standard
# 0     430.560.9453x2052         +43056094532052
# 1    984.604.4150x43467        +984604415043467
# 2         (430)785-7136            +14307857136
# 3     742-777-1185x4779         +74277711854779
# 4     (746)790-3735x459          +7467903735459
# 5  001-842-261-7325x122       +0018422617325122
# 6    (648)969-4686x5275         +64896946865275
# 7     (556)996-6659x782          +5569966659782
# 8          712-308-0106            +17123080106
# 9    262.292.3564x21820        +262292356421820

# %% [markdown]
# ### **B. Exploratory Data Analysis (EDA) (Pandas, Matplotlib & Seaborn)**
#
# 9.  What is the overall distribution of `transaction_amount`? Plot a histogram and a boxplot and interpret the outliers.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
axes[0].hist(df['transaction_amount'], bins=40, edgecolor='black')
axes[0].set_title('Histogram of Transaction Amount')
axes[0].set_xlabel('Transaction Amount')
axes[1].boxplot(df['transaction_amount'])
axes[1].set_title('Boxplot of Transaction Amount')
plt.tight_layout()
plt.show()

print('Skewness:', df['transaction_amount'].skew())
print('Stats:\n', df['transaction_amount'].describe())
# The distribution is strongly right-skewed with high-value outliers on the right.
# Out:
# Skewness: 13.19827402734552
# Stats:
#  count     1000.000000
# mean      1302.314480
# std       2091.339933
# min          4.300000
# 25%        380.445000
# 50%        945.100000
# 75%       1786.642500
# max      45066.670000
# Name: transaction_amount, dtype: float64

# %% [markdown]
# 10. Which are the top 10 best-selling products by total quantity sold? Create a bar chart.

# %%
top10 = df.groupby('product_name')['quantity'].sum().nlargest(10)
top10.plot(kind='barh', figsize=(10, 6), color='skyblue')
plt.title('Top 10 Best-Selling Products by Quantity Sold')
plt.xlabel('Total Quantity')
plt.gca().invert_yaxis()
plt.show()
print(top10)
# Out:
# product_name
# Network Key        77
# Bad Become         60
# About Daughter     10
# Above Sign         10
# Add Later          10
# Against Then       10
# Already Past       10
# As Husband         10
# Attorney Sister    10
# Ball Affect        10
# Name: quantity, dtype: int64

# %% [markdown]
# 11. How do sales vary by `day_of_week` and `month`? (Requires feature engineering first). Create appropriate visualizations.

# %%
df['transaction_date'] = pd.to_datetime(df['transaction_date'])
df['day_of_week'] = df['transaction_date'].dt.day_name()
df['month'] = df['transaction_date'].dt.month_name()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
sales_by_day = df.groupby('day_of_week')['transaction_amount'].sum().reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
sales_by_day.plot(kind='bar', ax=axes[0], color='orange')
axes[0].set_title('Sales by Day of Week')
sales_by_month = df.groupby('month')['transaction_amount'].sum()
sales_by_month.plot(kind='bar', ax=axes[1], color='green')
axes[1].set_title('Sales by Month')
plt.tight_layout()
plt.show()

# %% [markdown]
# 12. What is the most common `payment_method`? Visualize the proportions using a pie chart.

# %%
pay_counts = df['payment_method'].value_counts()
print('Most common payment method:', pay_counts.idxmax())
pay_counts.plot(kind='pie', autopct='%1.1f%%', figsize=(7, 7))
plt.title('Payment Method Proportions')
plt.ylabel('')
plt.show()
# Out:
# Most common payment method: Credit Card

# %% [markdown]
# 13. Show the distribution of transactions across different `shipping_address_state`s using a bar chart.

# %%
state_counts = df['shipping_address_state'].value_counts()
state_counts.plot(kind='bar', figsize=(12, 5), color='purple')
plt.title('Transactions by Shipping State')
plt.xlabel('State')
plt.ylabel('Number of Transactions')
plt.show()

# %% [markdown]
# 14. Is there a correlation between `item_price`, `quantity`, and `discount_applied_percent`? Calculate the correlation matrix and visualize it as a heatmap.

# %%
corr = df[['item_price', 'quantity', 'discount_applied_percent']].corr()
plt.figure(figsize=(6, 5))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()
print(corr)
# Out:
#                           item_price  quantity  discount_applied_percent
# item_price                  1.000000  0.024574                 -0.000368
# quantity                    0.024574  1.000000                  0.028405
# discount_applied_percent   -0.000368  0.028405                  1.000000

# %% [markdown]
# 15. Compare the average transaction amount across different devices (`device_used`) using a bar chart or boxplot.

# %%
sns.boxplot(data=df, x='device_used', y='transaction_amount')
plt.title('Transaction Amount by Device')
plt.show()
print(df.groupby('device_used')['transaction_amount'].mean())
# Out:
# device_used
# Desktop    1361.334046
# Mobile     1395.477215
# Tablet     1154.799112
# Name: transaction_amount, dtype: float64

# %% [markdown]
# ### **C. Feature Engineering (Pandas & NumPy)**
#
# 16. Create a `customer_age` column by calculating the age from `customer_dob`.

# %%
df['customer_dob'] = pd.to_datetime(df['customer_dob'])
today = pd.Timestamp.today()
df['customer_age'] = ((today - df['customer_dob']).dt.days / 365.25).astype(int)
df[['customer_dob', 'customer_age']].head()
# Out:
#   customer_dob  customer_age
# 0   1980-11-10            45
# 1   1982-09-02            44
# 2   2001-11-22            24
# 3   1941-06-08            85
# 4   1977-04-17            49

# %% [markdown]
# 17. Create a `transaction_day_of_week` column from the `transaction_date`.

# %%
df['transaction_day_of_week'] = df['transaction_date'].dt.day_name()
df[['transaction_date', 'transaction_day_of_week']].head()
# Out:
#   transaction_date transaction_day_of_week
# 0       2024-10-06                  Sunday
# 1       2021-05-17                  Monday
# 2       2025-06-06                  Friday
# 3       2024-11-13               Wednesday
# 4       2023-06-29                Thursday

# %% [markdown]
# 18. Create a `customer_tenure_days` column (days since `account_creation_date` to the transaction date).

# %%
df['account_creation_date'] = pd.to_datetime(df['account_creation_date'])
df['customer_tenure_days'] = (df['transaction_date'] - df['account_creation_date']).dt.days
df[['account_creation_date', 'transaction_date', 'customer_tenure_days']].head()
# Out:
#   account_creation_date transaction_date  customer_tenure_days
# 0            2023-12-19       2024-10-06                   292
# 1            2021-01-24       2021-05-17                   113
# 2            2023-01-18       2025-06-06                   870
# 3            2023-02-18       2024-11-13                   634
# 4            2023-03-13       2023-06-29                   108

# %% [markdown]
# 19. Create a `total_spend_per_customer` feature that aggregates all transaction amounts for each `customer_id`.

# %%
df['total_spend_per_customer'] = df.groupby('customer_id')['transaction_amount'].transform('sum')
df[['customer_id', 'transaction_amount', 'total_spend_per_customer']].head()
# Out:
#                             customer_id  transaction_amount  \
# 0  a027c0bd-1edf-4a3f-b7ef-f5c58d20b8d3              885.57
# 1  eaf947f0-a685-4afc-800b-f4e62524b6fc              906.74
# 2  47f33a62-e619-4aaf-a5c5-d4533f25e574             1669.43
# 3  195f9373-4509-4938-9c0f-8c809b7694a8             3199.98
# 4  0ed676db-664d-4ef8-8ce1-dc788f0c2bb7             2757.83
#
#    total_spend_per_customer
# 0                   9608.79
# 1                  17569.62
# 2                  11814.75
# 3                  13689.68
# 4                  12411.10

# %% [markdown]
# 20. Engineer a `days_since_last_login` feature based on the transaction date and the `last_login_date`.

# %%
df['last_login_date'] = pd.to_datetime(df['last_login_date'])
df['days_since_last_login'] = (df['transaction_date'] - df['last_login_date']).dt.days
df[['transaction_date', 'last_login_date', 'days_since_last_login']].head()
# Out:
#   transaction_date last_login_date  days_since_last_login
# 0       2024-10-06      2024-08-12                     55
# 1       2021-05-17      2021-05-11                      6
# 2       2025-06-06      2025-05-01                     36
# 3       2024-11-13      2024-10-17                     27
# 4       2023-06-29      2023-06-12                     17

# %% [markdown]
# 21. Create a categorical feature `price_tier` for items based on `item_price` (e.g., 'Low', 'Medium', 'High').

# %%
df['price_tier'] = pd.cut(
    df['item_price'],
    bins=[-np.inf, df['item_price'].quantile(0.33),
          df['item_price'].quantile(0.67), np.inf],
    labels=['Low', 'Medium', 'High'])
df[['item_price', 'price_tier']].head()
# Out:
#    item_price price_tier
# 0      125.88        Low
# 1      384.05       High
# 2      258.33     Medium
# 3      477.48       High
# 4      372.63       High

# %% [markdown]
# ### **D. Advanced Analysis & Business Insights**
#
# 22. Who are the top 10% of customers by `total_spend_per_customer`? Analyze their characteristics (e.g., common product categories, preferred device).

# %%
top10pct = df[df['total_spend_per_customer'] >= df['total_spend_per_customer'].quantile(0.90)]
print('Number of top 10% customers:', top10pct['customer_id'].nunique())
print('Most common categories:', top10pct['product_category'].value_counts().head())
print('Preferred device:', top10pct['device_used'].value_counts().idxmax())
print('Top states:', top10pct['shipping_address_state'].value_counts().head())
# Out:
# Number of top 10% customers: 8
# Most common categories: product_category
# Electronics    32
# Books          22
# Apparel        22
# Beauty         18
# Home Goods     15
# Name: count, dtype: int64
# Preferred device: Mobile
# Top states: shipping_address_state
# MP    5
# NJ    5
# CA    5
# SC    5
# PW    4
# Name: count, dtype: int64

# %% [markdown]
# 23. Does being a `loyalty_program_member` have a significant impact on the average transaction amount? Perform a comparative analysis.

# %%
df['loyalty_program_member'] = df['loyalty_program_member'].astype(str).str.strip().map(
    {'True': True, 'False': False, '1': True, '0': False}).astype(bool)
avg = df.groupby('loyalty_program_member')['transaction_amount'].mean()
print('Average transaction amount by loyalty membership:')
print(avg)
avg.plot(kind='bar', color=['salmon', 'steelblue'])
plt.title('Avg Transaction Amount: Loyalty vs Non-Loyalty')
plt.ylabel('Average Transaction Amount')
plt.xticks([0, 1], ['Non-Member', 'Member'], rotation=0)
plt.show()
# Out:
# Average transaction amount by loyalty membership:
# loyalty_program_member
# False    1327.425711
# True     1276.593259
# Name: transaction_amount, dtype: float64

# %% [markdown]
# 24. Identify customers who might be at risk of churning (e.g., `days_since_last_login` is high).

# %%
at_risk = df[df['days_since_last_login'] > df['days_since_last_login'].median()]
print('Number of at-risk customers:', at_risk['customer_id'].nunique())
# These customers haven't logged in recently and may be heading toward churn.
# Out:
# Number of at-risk customers: 99

# %% [markdown]
# 25. Analyze the refund rate (`transaction_status` == 'Refunded') across different `product_category`s. Which categories have the highest refund rates?

# %%
refund_rate = (df[df['transaction_status'] == 'Refunded'].groupby('product_category').size()
               / df.groupby('product_category').size()).sort_values(ascending=False)
refund_rate.plot(kind='bar', color='red')
plt.title('Refund Rate by Product Category')
plt.ylabel('Refund Rate')
plt.show()
print(refund_rate)
# Out:
# product_category
# Home Goods     0.272727
# Electronics    0.268293
# Beauty         0.266272
# Apparel        0.232432
# Books          0.226744
# dtype: float64

# %% [markdown]
# 26. Is there a relationship between `customer_age` and the `product_category` they purchase?

# %%
age_cat = pd.cut(df['customer_age'], bins=[0, 25, 35, 45, 60, 100])
table = pd.crosstab(age_cat, df['product_category'])
table.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Product Category Purchases by Age Group')
plt.show()

# %% [markdown]
# 27. Which `store_id` generates the most revenue?

# %%
store_rev = df.groupby('store_id')['transaction_amount'].sum().sort_values(ascending=False)
print('Store generating most revenue:')
print(store_rev.head())
store_rev.plot(kind='bar', color='teal')
plt.title('Revenue by Store')
plt.ylabel('Total Revenue')
plt.show()
# Out:
# Store generating most revenue:
# store_id
# STORE-002    95288.12
# STORE-018    77931.19
# STORE-006    77299.27
# STORE-016    75300.83
# STORE-009    73978.82
# Name: transaction_amount, dtype: float64

# %% [markdown]
# 28. How does the discount percentage (`discount_applied_percent`) affect the `quantity` of items sold?

# %%
disc_qty = df.groupby('discount_applied_percent')['quantity'].mean()
disc_qty.plot(kind='bar', figsize=(12, 5), color='gold')
plt.title('Average Quantity Sold by Discount %')
plt.ylabel('Average Quantity')
plt.show()
corr_dq = df[['discount_applied_percent', 'quantity']].corr().iloc[0, 1]
print('Correlation between discount and quantity:', round(corr_dq, 3))
# Out:
# Correlation between discount and quantity: 0.028

# %% [markdown]
# 29. What is the distribution of customer tenure? Are newer or older customers spending more?

# %%
df['customer_tenure_days'].hist(bins=30, edgecolor='black', figsize=(8, 5))
plt.title('Distribution of Customer Tenure (Days)')
plt.show()
tenure_vs_spend = df.groupby('customer_tenure_days')['transaction_amount'].mean()
newer = df[df['customer_tenure_days'] <= df['customer_tenure_days'].median()]['transaction_amount'].mean()
older = df[df['customer_tenure_days'] > df['customer_tenure_days'].median()]['transaction_amount'].mean()
print('Avg spend newer customers:', round(newer, 2))
print('Avg spend older customers:', round(older, 2))
# Out:
# Avg spend newer customers: 1324.52
# Avg spend older customers: 1280.11

# %% [markdown]
# 30. Based on your entire analysis, provide three concrete, data-driven recommendations to "ByteBloom" to help them achieve their business goals.

# %%
print('''
Based on the analysis, here are three data-driven recommendations for ByteBloom:

1. SHIFT TO TARGETED MARKETING (Retention): The broad one-size-fits-all campaigns are fading.
   Use the top-10% high-value customer profile (categories, device, location) to build look-alike
   audiences and personalized offers instead of mass ads.

2. BOOST LOYALTY PROGRAM: Loyalty members spend more on average. Push enrollment with targeted
   incentives and add tiered rewards tied to RFM (Recency, Frequency, Monetary) to raise CLV and reduce churn.

3. RETAIN AT-RISK & OPTIMIZE INVENTORY: Re-engage customers with high days-since-last-login via win-back
   campaigns, and use product/refund-rate insights to stock winning categories while cutting categories
   with high refund rates to free up capital.
''')
# Out:
# Based on the analysis, here are three data-driven recommendations for ByteBloom:
#
# 1. SHIFT TO TARGETED MARKETING (Retention): The broad one-size-fits-all campaigns are fading.
#    Use the top-10% high-value customer profile (categories, device, location) to build look-alike
#    audiences and personalized offers instead of mass ads.
#
# 2. BOOST LOYALTY PROGRAM: Loyalty members spend more on average. Push enrollment with targeted
#    incentives and add tiered rewards tied to RFM (Recency, Frequency, Monetary) to raise CLV and reduce churn.
#
# 3. RETAIN AT-RISK & OPTIMIZE INVENTORY: Re-engage customers with high days-since-last-login via win-back
#    campaigns, and use product/refund-rate insights to stock winning categories while cutting categories
#    with high refund rates to free up capital.
