# %% [markdown]
# Que 1 :- Create a program that simulates an ATM login. The user has a maximum of 3 attempts to enter the correct PIN (e.g., 1234).
#
#   - If the user enters the correct PIN, print "Access Granted" and break the loop.
#
#   - If they enter the wrong PIN, print "Incorrect PIN. Attempts remaining: X" and continue to the next attempt.
#
#   - If they fail 3 times, print "Account Locked."

# %%
correct_pin = '1234'
attempts = 3

while attempts > 0:
  user_inp = input(f'Enter the correct PIN ({attempts} remaining)L ')
  if user_pin == correct_pin:
    print('Access Granted')
    break
  attempts -= 1
  if attempts > 0:
    print(f' You have entered an incorrect PIN. Attempts Remaining {attempts}')
  else:
    print('Account is Locked!!!')

# %% [markdown]
# Create a shopping list builder where the user can type in items.
#
#   - If the item is already in the list, print "Item already exists" and continue without adding it.
#
#   - If the user types "done", break the loop and print the final alphabetized list.
#
#   - **Constraint:** If the user enters a number instead of a string (e.g., "5" instead of "Apples"), use isdigit() to check; print "Invalid input" and continue.

# %%
shopping_lst = []
lst_of_exit = ['done', 'ok', 'thank you']
while True:
  item = input('Enter the item: ').strip()

  # if user enters 'done'
  if item.lower() in  lst_of_exit:
    break

  # if user enters a digit value
  if item.isdigit():
    print('It is an invalid input. Please enter an item not a number.')
    continue

  # if item is already existing in shopping list
  if item.lower() in shopping_lst:
    print(f'{item} is already exisitng !!!')
    continue

  # If item is valid input and does not exist in shopping list
  if item:
    shopping_lst += [item.lower()]
    print(f'{item} is added')

print('\n Shopping List Items are as below:\n')
for items in shopping_lst:
  print(items)
# Out:
# Enter the item: 5
# It is an invalid input. Please enter an item not a number.
# Enter the item: apple
# apple is added
# Enter the item: banana
# banana is added
# Enter the item: lemon
# lemon is added
# Enter the item: apple
# apple is already exisitng !!!
# Enter the item: done
#
#  Shopping List Items are as below:
#
# apple
# banana
# lemon

# %% [markdown]
# Que 3: Write a program that asks the user to input numbers one by one.
#
#   - The program should keep a running total (sum) of the numbers.
#
#   - If the user enters a number that is a multiple of 5, it should not be added to the sum (continue).
#
#   - If the user enters a negative number, the loop should end (break).
#
#   - Finally, print the total sum.

# %%
total_sum = 0

while True:
  num = int(input('ENter a number (ENter a negative number to end): '))
  if num < 0:
    print('Negtive number entered. Ending the program.')
    break
  elif num%5 == 0:
    print(f'Skipping {num} as it is multiple of 5')
    continue
  else:
    total_sum += num
    print(f'Added {num}')
print(f'\n Total sum is {total_sum}')
# Out:
# ENter a number (ENter a negative number to end): 4
# Added 4
# ENter a number (ENter a negative number to end): 45
# Skipping 45 as it is multiple of 5
# ENter a number (ENter a negative number to end): 32
# Added 32
# ENter a number (ENter a negative number to end): 23
# Added 23
# ENter a number (ENter a negative number to end): -9
# Negtive number entered. Ending the program.
#
#  Total sum is 59

# %%
19876545678237237737//2

sqrt(num)
# Out:
# 9938272839118618868

# %%
import math
math.sqrt(19876545678237237737)
# Out:
# 4458311976.324362

# %%
import math
num = int(input('Enter a number to check whether it is prime or not?: '))
start_num_divisible = 2
check_till = math.floor(math.sqrt(num))
while start_num_divisible <= check_till:
  if num % start_num_divisible== 0:
    print(f'{num} is divisible by {start_num_divisible}. So not a prime Number.')
    break
  else:
    start_num_divisible+=1
else:
  print(f"{num} is a prime number")
# Out:
# Enter a number to check whether it is prime or not?: 11373373373
# 11373373373 is a prime number

# %%
# List

# LIst is a collection of multiple values and values can be of any type.
# any value or group of values kept inside [] - list

emp_name = 'Suresh'
emp_age = 28
emp_sal = 45987.90
emo_email = 'suresh@learnbay.co'

emp_lst = ['Suresh', 28, 45987.90, 'suresh@learnbay.co']
print(emp_lst, type(emp_lst))
# Out:
# ['Suresh', 28, 45987.9, 'suresh@learnbay.co'] <class 'list'>

# %%
# How elements insode the list is stored
lst = [10, 20, 'Python', [10, 20, 30], 40]
# print(lst, id(lst))
# print(lst[0], id(lst[0]))

# print(lst[3][0])
# print(lst[-2][0])

# print(lst[0] is lst[3][0])

print(id(lst[0]), id(lst[3][0]))
# Out:
# 11645640 11645640

# %%
# Properties of list
# List is a collection if Heterogeneous elements

my_lst = [10, 10.20, 10+20j, 'Python', None, True, [1, 2, 3], (1, 2, 3), {1:100}, {100, 200}]
print(my_lst, type(my_lst))
# Out:
# [10, 10.2, (10+20j), 'Python', None, True, [1, 2, 3], (1, 2, 3), {1: 100}, {200, 100}] <class 'list'>

# %%
# List Creation

# If you know the elements in advance
# emp_detail1 = ['Abhishek', 101, 10000.00]
# print(emp_detail1, type(emp_detail1))

# Empty list
# lst = []
# print(lst, type(lst))
# # # print(lst[0], type(lst))
# empty_lst = list()
# print(empty_lst, type(empty_lst))


# Creating a list using list function
# list(iterable)
# Iterable - Any object which implements __iter__ method.
# print('__iter__' in dir(int))
# print('__iter__' in dir(float))
# print('__iter__' in dir(None))
# print('__iter__' in dir(complex))
# print('__iter__' in dir(bool))

# print('__iter__' in dir(str))
# print('__iter__' in dir(list))
# print('__iter__' in dir(tuple))
# print('__iter__' in dir(set))
# print('__iter__' in dir(frozenset))
# print('__iter__' in dir(dict))
# print('__iter__' in dir(range))

lst = list("'Python', 1, 2")          # # A list will be created as every element of string will become an individual element of the list
print(lst)

# lst = list([1, 2, 3, 4, 5])
# print(lst, type(lst))

# lst = list({1, 2, 3, 4, 5})
# print(lst, type(lst))

# lst = list({1:100, 2:200, 3:300})
# print(lst, type(lst))

# print(list(10))     # TypeError: 'int' object is not iterable

print(list(range(-1, -10, -1)))
# Out:
# ["'", 'P', 'y', 't', 'h', 'o', 'n', "'", ',', ' ', '1', ',', ' ', '2']
# [-1, -2, -3, -4, -5, -6, -7, -8, -9]

# %%
range(-1, -10, -1)
# Out:
# range(-1, -10, -1)
