# %%
# methods which are used to check the elements are alphabets/numeric or alphanumeric
# These methods always return boolean Value - True or


# isalnum - It checks whether all characters are either alphabet or numeric or alphanumeric or not
# isalpha - It checks whether all characters are alphabet or not
# isdecimal - It checks whether all characters are decimal or not
# isdigit - It checks whether all characters are digit or not
# isnumeric - It checks whether all characters are numeric or not

my_str1 = 'ThisisPythonclass'
my_str2 = 'ThisisPythonclassno52'
my_str3 = '764522716352'
# print(my_str1.isalnum())
# print(my_str2.isalnum())
# print(my_str3.isalnum())

# print(my_str1.isalpha())
# print(my_str2.isalpha())

# Decimal - Decimal values/number - Superscript and subscript are not the deinmcal numbers
# print('-123'.isdecimal())
# print('123.45'.isdecimal())
# print('12⁴'.isdecimal())
# print('½'.isdecimal())
# print('12₂'.isdecimal())

# print('123'.isdecimal())

# Digit - Digit values/number - Superscript and subscript
# print('-123'.isdigit())
# print('123.45'.isdigit())
# print('12⁴'.isdigit())
# print('½'.isdigit())
# print('12₂'.isdigit())

# Isnumeric - any number e.g roman number (Float, -negative numbers not numeric)
# print('123'.isnumeric())
# print('-123'.isnumeric())
# print('123.45'.isnumeric())
# print('12⁴'.isnumeric())
# print('½'.isnumeric())
# print('12₂'.isnumeric())
# print('Ⅰ'.isnumeric())
# print('Ⅶ'.isnumeric())
# '10+20j'.isnumeric()

'Ⅰ'.isnumeric()
# Out:
# True

# %%
# 'isspace' - it checks that in the given string each character is a space character or not
# This method also return Boolean value

print('This is Python class'.isspace())
print('    '.isspace())
print('\t\n\v\f'.isspace())
# Out:
# False
# True
# True

# %%
# 'isidentifier' - the name you have given in string is a valid identifier or not#
# Exception - reserved words and keywords are forbidden -

# '1num'.isidentifier()
# '_num'.isidentifier()

# 'for'.isidentifier()

import keyword
print(keyword.iskeyword('for'))
# Out:
# True

# %%
# str_name.startswith('sub_str'[, start_index, stop_index]) - True/False


my_str = 'This is Python class'
# print(my_str.startswith('T'))
# print(my_str.startswith('Thi'))
# print(my_str.startswith('is'))
# print(my_str.startswith('is', 5, 10))
# print(my_str.startswith('is', 5, 7))

# str_name.endswith('sub_str'[, start_index, stop_index]) - True/False
# print(my_str.endswith('s'))
# print(my_str.endswith('class'))
# print(my_str.endswith('Py'))
print(my_str.endswith('Py', 5, 10))
# print(my_str.endswith('is', 5, 7))
# Out:
# True

# %%
# str_name.find('sub_str'[, start_index, stop_index])
# find method does the search from left to right and returns the +ve index of the
      # first occurrence of the sub_str in str_name
# If the sub_str is not found then it returns -1
# If sub_str is a group of characters then it will return the index of
      # first character of matching sub_str

my_str = 'This is Python class'
# print(my_str.find('i'))
# print(my_str.find('is'))
# print(my_str.find('Pn'))
# print(my_str.find('Python', 5, 14))


# str_name.rfind('sub_str'[, start_index, stop_index])
# rfind method does the search from right to left and returns the +ve index of
          # the first occurrence of the sub_str in str_name
# If the sub_str is not found then it returns -1
# If sub_str is a group of characters then it will return the index of
          # first character of matching sub_str

my_str = 'This is Python class'
print(my_str.rfind('i'))
print(my_str.rfind('is'))
print(my_str.rfind('Pn'))
print(my_str.rfind('Python', 5, 14))
# Out:
# 5
# 5
# -1
# 8

# %%
# WAP which takes email id from user and gives me user_name and domain name separately
# Hint - use find method and concept we learnt till now

# 'abc@gmail.com'

# Enter your email id: Abs@gmail.com
# User Name: Abs
# Domain Name: gmail.com

# %%
# 'abhishek@gmail.com'

# email = input("Enter the email : \n")
# index = email.find("@")
# print("Username is ", email[:index])
# print("Domain is ", email[index + 1:])
# Out:
# Enter the email :
# abhishek@gmail.com
# Username is  abhishek
# Domain is  gmail.com

# %%
user_id = input('Enter your email id: ')
user_name,domain_name = user_id[:user_id.find('@')], user_id[user_id.find('@')+1:]

print('User Name:', user_name)
print('Domain Name:', domain_name)
# Out:
# Enter your email id: abc@gmaul.com
# User Name: abc
# Domain Name: gmaul.com

# %%
# str_name.index('sub_str'[, start_index, stop_index])
# index method does the search from left to right and returns the +ve index of
          # the first occurrence of the sub_str in str_name
# If the sub_str is not found then it returns ValueError
# If sub_str is a group of characters then it will return the index of
          # first character of matching sub_str


my_str = 'This is Python class'
sub_str = 'is'
# print(my_str[my_str.find(sub_str)])
# print(my_str[my_str.find('Y')])
# print(my_str[my_str.index('Y')])
# print(my_str)

# my_str = 'This is Python class'
# sub_str = 'is'
# print(my_str.index(sub_str))

# str_name.rindex('sub_str'[, start_index, stop_index])
# rindex method does the search from right to left and returns the +ve index of the first occurrence of the sub_str in str_name
# If the sub_str is not found then it returns ValueError
# If sub_str is a group of characters then it will return the index of first character of matching sub_str

my_str = 'This is Python class'
sub_str = 'is'
print(my_str.rindex(sub_str))
# Out:
# 5

# %%
# str_name.count('sub_str',[, start_index, stop_index])

my_str = 'This is Python class'
my_str.count('s')
print(my_str.count('is'))
print(my_str.count('is', 5, 10))
print(my_str.count('is', 6, 10))
# Out:
# 2
# 1
# 0

# %%
# String formatiing

# center, rjust, ljust, zfill

# str_name.center(length of output string, fill char = ' ')

# **************************************************
#               Welcome to my Program
# **************************************************


my_str = 'Welcome to my Program'
print('*'*50)
print(my_str.center(50, '+'))
print('*'*50)
# Out:
# **************************************************
# ++++++++++++++Welcome to my Program+++++++++++++++
# **************************************************

# %%
# str_name.ljust(length of output string, fill char = ' ')

# **************************************************
# Welcome to my Program
# **************************************************

my_str = 'Welcome to my Program'
print('*'*50)
print(my_str.ljust(50))
print('*'*50)
# Out:
# **************************************************
# Welcome to my Program
# **************************************************

# %%
# str_name.rjust(length of output string, fill char = ' ')
# **************************************************
#                              Welcome to my Program
# **************************************************

my_str = 'Welcome to my Program'
print('*'*50)
print(my_str.rjust(50))
print('*'*50)
# Out:
# **************************************************
#                              Welcome to my Program
# **************************************************

# %%
# laptop                                     1200.00
# mouse                                      0010.00
# monitor                                    1245.75


print('10.00'.zfill(7))
# Out:
# 0010.00

# %%
# capitalize, title, upper, lower, swapcase - str
# isalpha, isalnum, isnumeric, isdigit, isdecimal, isspace, isidentifier - Boolean
# startswith, endswith - Boolean
# find, rfind, index, rindex, count - int
# center, zfill, rjust, ljust - str

# %%
# laptop                                     1200.00
# mouse                                      0010.00

print('laptop'.ljust(25)+'1200.00'.rjust(25))
print('mouse'.ljust(25)+'10.00'.zfill(7).rjust(25))
# Out:
# laptop                                     1200.00
# mouse                                      0010.00

# %%
# --------------------------------------------------  # 50
# -----------------Financial report-----------------
# --------------------------------------------------
# Item                                         Price
# --------------------------------------------------
# Laptop                                    01200.50
# Mouse                                     00025.00
# Monitor                                   00350.75
# Mouse                                     00025.00


print('-'*50)
print('Financial Report'.center(50, '-'))
print('-'*50)
print('Item'.ljust(25)+'Price'.rjust(25))
print('-'*50)
print('Laptop'.ljust(25)+'1200.50'.zfill(8).rjust(25))
# Out:
# --------------------------------------------------
# -----------------Financial Report-----------------
# --------------------------------------------------
# Item                                         Price
# --------------------------------------------------
# Laptop                                    01200.50

# %%
# strip, lstrip, rstrip - it removs the spaces from ends from the string -> str
# str_name.strip([chars = ' ']) - to remove the spaces/chars from both sides
# str_name.lstrip([chars = ' ']) - to remove the spaces/chars from left sides
# str_name.rstrip([chars = ' ']) - to remove the spaces/chars from right sides


# my_str = '       This is        Python     class.        '
# print(my_str.strip())
# print(my_str.lstrip())
# print(my_str.rstrip())


# my_str = '++++++++++This is++++ Python ++++ class+++++++'
# print(my_str.strip('+'))
# print(my_str.lstrip('+'))
# print(my_str.rstrip('+'))
# print(my_str.rstrip())

user_input = input('Enter Your Name: ').strip()
print(user_input)
# Out:
# This is++++ Python ++++ class
# This is++++ Python ++++ class+++++++
# ++++++++++This is++++ Python ++++ class
# ++++++++++This is++++ Python ++++ class+++++++

# %%
# replace
# str_name.replace(old_sub_str, new_sub_str[, count])   -> str
# Replaces all the occurrences of old_sub_str with new_sub_str and returns a new string object

my_str = 'This is Python class'
# res_str = my_str.replace('s', 'z')

# res_str = my_str.replace('s', 'z', 3)

res_str = my_str.replace('is', 'eez', 3)
print(my_str)
print(res_str)
# Out:
# This is Python class
# Theez eez Python class

# %%
# split and join
# my_str.split(sep = None, maxsplit = -1)         -> List
# It splits the string with space characters if sep is not specified
# Maxsplit = -1, max no of splits
# returns a list of strings

# if maxsplit = n then in list you will always get n+1 string as output


my_str = '       This is        Python     class        '
# print(my_str.split())
# print(my_str.split(maxsplit = 2))
print(my_str.split(' '))
# Out:
# ['', '', '', '', '', '', '', 'This', 'is', '', '', '', '', '', '', '', 'Python', '', '', '', '', 'class', '', '', '', '', '', '', '', '']

# %%
#'sep'.join(list or tuple of strings)

# Expected output - 'This is Python class'
lst_of_str = ['This', 'is', 'Python', 'class']
' '.join(lst_of_str)
# Out:
# 'This is Python class'

# %%
my_str = 'peter piper picked a peck of pickled peppers'

# Output1:- 'sreppep delkcip fo kcep a dekcip repip retep'
# print(my_str[::-1])



# Output2:- 'retep repip dekcip a kcep fo delkcip sreppep'
# Step 1
# print(my_str[::-1])

# Step 2
# my_str[::-1].split()

# Step 3
# my_str[::-1].split()[::-1]

# Step 4
' '.join(my_str[::-1].split()[::-1])

# Output3:- 'peppers pickled of peck a picked piper peter'
print(' '.join(my_str.split()[::-1]))
# Out:
# peppers pickled of peck a picked piper peter
