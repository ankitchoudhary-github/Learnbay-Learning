# %%
# Function

# Functions in Python are reusable pieces of code allowing for repeated use without redundancy.

# DRY - Do not repeat yourself

# 1. Reuse
# 2. Readability
# 3. Maintainability

# To define a function in Python - def
# Out:
# 1

# %%
# Syntax of function definition (Function definition is not equal to function call/Execution)

def func_name(parameters):    # Parameter is optional
  # Logic
  # Code
  # Body
  return value          # Optional - When we do not write the return statement then it returns None

# Normal code
# Normal Code

# Function call - excutes the function or code written inside the function
func_name(arguments)      # Arguments are mandatory if parameters are given while function definition

# Normal Code
# Normal Code

# Arguments are the actual values which are passed during function call
# Parameters are the placeholder which holds the arguments

# %%
# Function - defined outside of the class with def
# method - defined inside of the class with def

# %%
class Employee:
  def emp_info(self, emp_id):
    return self.emp_id

emp = Employee()
emp.emp_info('101')

# %%
help(str.ljust)
# Out:
# Help on method_descriptor:
#
# ljust(self, width, fillchar=' ', /) unbound builtins.str method
#     Return a left-justified string of length width.
#
#     Padding is done using the specified fill character (default is a space).

# %%
'Laptop'.ljust(25)+'1200.50'.zfill(8)

# %%
my_str = input()
out_lst = []
word = ''
for ind in range(len(my_str)):
  if my_str[ind] == ' ':
    out_lst += [word]
    word = ''
  else:
    word += my_str[ind]
else:
  out_lst += [word]
print(out_lst)
# Out:
# This is Python class
# ['This', 'is', 'Python', 'class']

# %%
my_str = '       This is       Python   class       '
' '.join(my_str.strip().split())
# Out:
# 'This is Python class'

# %%
# Defining the function without parameter

def my_split():
  my_str = input()
  out_lst = []
  word = ''
  for ind in range(len(my_str)):
    if my_str[ind] == ' ':
      out_lst += [word]
      word = ''
    else:
      word += my_str[ind]
  else:
    out_lst += [word]
  print(out_lst)

# %%
my_split()
# Out:
# This is Python class
# ['This', 'is', 'Python', 'class']

# %%
# Function definition - Define that what task has to be perfomred when we call the function

# %%
def shopping_cart(item1, item2, item3):
  return item1+item2+item3

shopping_cart(10, 100, 500)

# Parameters - name which are going to hold the arguments
# Arguments - Actual value which we pass during the function call

# %%
# Docstring - are kept inside '''...''' just below def statement in a function definition

# Details of the function

def my_split():
  '''split(self, /, sep=None, maxsplit=-1) unbound builtins.str method
    Return a list of the substrings in the string, using sep as the separator string.

      sep
        The separator used to split the string.

        When set to None (the default value), will split on any whitespace
        character (including \n \r \t \f and spaces) and will discard
        empty strings from the result.
      maxsplit
        Maximum number of splits.
        -1 (the default value) means no limit.

    Splitting starts at the front of the string and works to the end.

    Note, str.split() is mainly useful for data that has been intentionally
    delimited.  With natural text that includes punctuation, consider using
    the regular expression module.'''
  my_str = input()
  out_lst = []
  word = ''
  for ind in range(len(my_str)):
    if my_str[ind] == ' ':
      out_lst += [word]
      word = ''
    else:
      word += my_str[ind]
  else:
    out_lst += [word]
  print(out_lst)
# print(my_split.__doc__)
print(help(my_split))
# Out:
# Help on function my_split in module __main__:
#
# my_split()
#     split(self, /, sep=None, maxsplit=-1) unbound builtins.str method
#     Return a list of the substrings in the string, using sep as the separator string.
#
#       sep
#         The separator used to split the string.
#
#         When set to None (the default value), will split on any whitespace
#         character (including
#             and spaces) and will discard
#         empty strings from the result.
#       maxsplit
#         Maximum number of splits.
#         -1 (the default value) means no limit.
#
#     Splitting starts at the front of the string and works to the end.
#
#     Note, str.split() is mainly useful for data that has been intentionally
#     delimited.  With natural text that includes punctuation, consider using
#     the regular expression module.
#
# None

# %%
print(dir(my_split))
# Out:
# ['__annotations__', '__builtins__', '__call__', '__class__', '__closure__', '__code__', '__defaults__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__get__', '__getattribute__', '__getstate__', '__globals__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__kwdefaults__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__qualname__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__type_params__']

# %%
# Parameters are optional
# Indentation is essential: all function code must be indented beneath the def statement.
# The return statement is optional—if omitted, Python returns None by default.

# %%
def my_func_add(val1, val2):
  res = val1+val2
  print(res)

my_var = my_func_add(10, 20)
print(f'output to function my_func_add -> {my_var}')

# %%
def my_func_add(val1, val2):
  res = val1+val2
  print(res)
  return res
  a = 100+90

my_var = my_func_add(10, 20)
print(f'output to function my_func_add -> {my_var}')

# %%
my_str = 'This is Python class'
res_str_1 = my_str.split()
'->'.join(res_str_1).split('->')

# %%
generate_invoice(shopping_cart())

# %%
# Note - return is end of the function call so any code written after return statement in function definitionwill not be executed

# %%
def my_func_add(val1, val2):
  res = val1+val2
  print(res)
  return res
  print(val1)
  print(val2)

my_var = my_func_add(10, 20)
print(f'output to function my_func_add -> {my_var}')
# Out:
# 30
# output to function my_func_add -> 30

# %%
price_lst = ['1.9k', '0.9k', '1999', '1999.00', '2.5k', '4k', '2999/-']
out_price_lst = [1900, 999, 1999, 1999, 2500, 4000, 2999]

# %%
def convert_price(price):
    price = price.lower().replace("/-", "")

    print(price)
    if price.endswith("k"):
        fixed_price = int(float(price[:-1]) * 1000)
        print(fixed_price)
        return fixed_price
    return int(float(price))


price_lst = ['1.9k', '0.9k', '1999', '1999.00', '2.5k', '4k', '2999', '2999/-']

out_price_lst = [convert_price(price) for price in price_lst]

print(out_price_lst)
# Out:
# 1.9k
# 1900
# 0.9k
# 900
# 1999
# 1999.00
# 2.5k
# 2500
# 4k
# 4000
# 2999
# 2999
# [1900, 900, 1999, 1999, 2500, 4000, 2999, 2999]

# %%
def convert_price(price):
    price = price.lower().replace("/-", "")

    if price.endswith("k"):
        return int(float(price[:-1]) * 1000)
    return int(float(price))


price_lst = ['1.9k', '0.9k', '1999', '1999.00', '2.5k', '4k', '2999', '2999/-']

out_price_lst = [convert_price(price) for price in price_lst]

print(out_price_lst)
# Out:
# [1900, 900, 1999, 1999, 2500, 4000, 2999, 2999]

# %%
price_lst = ['1.9k', '0.9k', '1999', '1999.00', '2.5k', '4k', '2999/-']

def convert_price(price_lst):
  return [int(float(price.strip()[:-1])*1000) if price.strip().endswith('k') else int(float(price.replace('/-', ''))) if price.strip().endswith('/-') \
          else int(float(price.strip())) for price in price_lst]
convert_price(price_lst)
# Out:
# [1900, 900, 1999, 1999, 2500, 4000, 2999]

# %%
category = ['Fashion', 'fashion', "Men's Fashion", "Women's Fashion", 'Kitchen Accessories', 'Home & Kitchen', 'Apparel'
            "Kid's Fashion", "kid's fashion", 'Electronics', "HOME & KITCHEN", "ELECTRONICS", "ELEC", "GADGETS", 'gadgets']
# Fashion
# Electronics
# Home & Kitchen

out_category = ['Fashion', 'Fashion', 'Fashion', 'Fashion', 'Home & Kitchen', 'Home & Kitchen', 'Fashion'...]
