# %%
import numpy as np
import pandas as pd

# %%
Series - Data With one columns
DataFrame - Data with multiple columns

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# How a dataframe looks like
crime_data = pd.read_csv('/content/drive/MyDrive/datasets/Crime in the United States.csv')
crime_data
# Out:
#     Year  Violent Crime Rate  Robbery Rate  Property Crime Rate  \
# 0   2000               506.5         145.0               3618.3
# 1   2001               504.5         148.5               3658.1
# 2   2002               494.4         146.1               3630.6
# 3   2003               475.8         142.5               3591.2
# 4   2004               463.2         136.7               3514.1
# 5   2005               469.0         140.8               3431.5
# 6   2006               479.3         150.0               3346.6
# 7   2007               471.8         148.3               3276.4
# 8   2008               458.6         145.9               3214.6
# 9   2009               431.9         133.1               3041.3
# 10  2010               404.5         119.3               2945.9
# 11  2011               387.1         113.9               2905.4
# 12  2012               387.8         113.1               2868.0
# 13  2013               367.9         109.1               2730.7
#
# ...

# %%
crime_data['Violent Crime Rate']
# Out:
# 0     506.5
# 1     504.5
# 2     494.4
# 3     475.8
# 4     463.2
# 5     469.0
# 6     479.3
# 7     471.8
# 8     458.6
# 9     431.9
# 10    404.5
# 11    387.1
# 12    387.8
# 13    367.9
# Name: Violent Crime Rate, dtype: float64

# %%
river = ['Missouri', 'Mississippi', 'Yukon',
         'Tennessee', 'Brazos']

# %%
river_ser = pd.Series(river)
print(river_ser)
# Out:
# 0       Missouri
# 1    Mississippi
# 2          Yukon
# 3      Tennessee
# 4         Brazos
# dtype: object

# %%
(river_ser[0])
# Out:
# 'Missouri'

# %%
river_ser[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1084/3801363068.py in <cell line: 0>()
# ----> 1 river_ser[-1]
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# ...

# %%
river_ser
# Out:
# 0       Missouri
# 1    Mississippi
# 2          Yukon
# 3      Tennessee
# 4         Brazos
# dtype: object

# %%
print(river_ser[1:3])
# Out:
# 1    Mississippi
# 2          Yukon
# dtype: object

# %%
ser_river = pd.Series(river, ['riv_'+str(i) for i in range(1, len(river)+1)])
ser_river
# Out:
# riv_1       Missouri
# riv_2    Mississippi
# riv_3          Yukon
# riv_4      Tennessee
# riv_5         Brazos
# dtype: object

# %%
ser_river.rename('River_name')
# Out:
# riv_1       Missouri
# riv_2    Mississippi
# riv_3          Yukon
# riv_4      Tennessee
# riv_5         Brazos
# Name: River_name, dtype: object

# %%
print(ser_river['riv_2'])
# Out:
# Mississippi

# %%
# In the case of custom indexing, stop index is also included in slicing
# whereas in case of 0 based indexing stop index is not included in slicing

# %%
print(ser_river['riv_2':'riv_4'])
# Out:
# riv_2    Mississippi
# riv_3          Yukon
# riv_4      Tennessee
# dtype: object

# %%
print(ser_river[1:4])
# Out:
# riv_2    Mississippi
# riv_3          Yukon
# riv_4      Tennessee
# dtype: object

# %%
sales_data = {2000:'89 Cr', 2005:'159 Cr', 2010:'279 Cr', 2015:'300 Cr', 2020:'315 Cr'}
sales_data
# Out:
# {2000: '89 Cr', 2005: '159 Cr', 2010: '279 Cr', 2015: '300 Cr', 2020: '315 Cr'}

# %%
pd.Series(sales_data)
# Out:
# 2000     89 Cr
# 2005    159 Cr
# 2010    279 Cr
# 2015    300 Cr
# 2020    315 Cr
# dtype: object

# %%
data = {
    "Name": ["Riya", "Arjun", "Kabir"],
    "Maths": [85, 60, 95],
    "Science": [90, 75],
    "English": [70, 80, 92]
}
df = pd.DataFrame(data)
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1084/3602871524.py in <cell line: 0>()
#       5     "English": [70, 80, 92]
#       6 }
# ----> 7 df = pd.DataFrame(data)
#       8 print(df)
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     776         elif isinstance(data, dict):
#     777             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779         elif isinstance(data, ma.MaskedArray):
#     780             from numpy.ma import mrecords
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
crime_data
# Out:
#     Year  Violent Crime Rate  Robbery Rate  Property Crime Rate  \
# 0   2000               506.5         145.0               3618.3
# 1   2001               504.5         148.5               3658.1
# 2   2002               494.4         146.1               3630.6
# 3   2003               475.8         142.5               3591.2
# 4   2004               463.2         136.7               3514.1
# 5   2005               469.0         140.8               3431.5
# 6   2006               479.3         150.0               3346.6
# 7   2007               471.8         148.3               3276.4
# 8   2008               458.6         145.9               3214.6
# 9   2009               431.9         133.1               3041.3
# 10  2010               404.5         119.3               2945.9
# 11  2011               387.1         113.9               2905.4
# 12  2012               387.8         113.1               2868.0
# 13  2013               367.9         109.1               2730.7
#
# ...

# %%
crime_data.head(10)
# Out:
#    Year  Violent Crime Rate  Robbery Rate  Property Crime Rate  Burglary Rate  \
# 0  2000               506.5         145.0               3618.3          728.8
# 1  2001               504.5         148.5               3658.1          741.8
# 2  2002               494.4         146.1               3630.6          747.0
# 3  2003               475.8         142.5               3591.2          741.0
# 4  2004               463.2         136.7               3514.1          730.3
# 5  2005               469.0         140.8               3431.5          726.9
# 6  2006               479.3         150.0               3346.6          733.1
# 7  2007               471.8         148.3               3276.4          726.1
# 8  2008               458.6         145.9               3214.6          733.0
# 9  2009               431.9         133.1               3041.3          717.7
#
#    Larceny Theft Rate  Vehicle Theft Rate
# 0              2477.3               412.2
# ...

# %%
crime_data.tail()
# Out:
#     Year  Violent Crime Rate  Robbery Rate  Property Crime Rate  \
# 9   2009               431.9         133.1               3041.3
# 10  2010               404.5         119.3               2945.9
# 11  2011               387.1         113.9               2905.4
# 12  2012               387.8         113.1               2868.0
# 13  2013               367.9         109.1               2730.7
#
#     Burglary Rate  Larceny Theft Rate  Vehicle Theft Rate
# 9           717.7              2064.5               259.2
# 10          701.0              2005.8               239.1
# 11          701.3              1974.1               230.0
# 12          672.2              1965.4               230.4
# 13          610.0              1899.4               221.3

# %%
crime_data.shape
# Out:
# (14, 7)

# %%
crime_data.columns
# Out:
# Index(['Year', 'Violent Crime Rate', 'Robbery Rate', 'Property Crime Rate',
#        'Burglary Rate', 'Larceny Theft Rate', 'Vehicle Theft Rate'],
#       dtype='object')

# %%
crime_data.dtypes
# Out:
# Year                     int64
# Violent Crime Rate     float64
# Robbery Rate           float64
# Property Crime Rate    float64
# Burglary Rate          float64
# Larceny Theft Rate     float64
# Vehicle Theft Rate     float64
# dtype: object

# %%
crime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Year                 14 non-null     int64
#  1   Violent Crime Rate   14 non-null     float64
#  2   Robbery Rate         14 non-null     float64
#  3   Property Crime Rate  14 non-null     float64
#  4   Burglary Rate        14 non-null     float64
#  5   Larceny Theft Rate   14 non-null     float64
#  6   Vehicle Theft Rate   14 non-null     float64
# dtypes: float64(6), int64(1)
# memory usage: 916.0 bytes

# %%
crime_data.describe()
# Out:
#             Year  Violent Crime Rate  Robbery Rate  Property Crime Rate  \
# count    14.0000           14.000000     14.000000            14.000000
# mean   2006.5000          450.164286    135.164286          3269.478571
# std       4.1833           46.164899     14.843523           321.355708
# min    2000.0000          367.900000    109.100000          2730.700000
# 25%    2003.2500          411.350000    122.750000          2969.750000
# 50%    2006.5000          466.100000    141.650000          3311.500000
# 75%    2009.7500          478.425000    146.050000          3571.925000
# max    2013.0000          506.500000    150.000000          3658.100000
#
#        Burglary Rate  Larceny Theft Rate  Vehicle Theft Rate
# count      14.000000           14.000000           14.000000
# mean      715.014286         2211.014286          343.435714
# std        36.169491          206.552857           88.989598
# min       610.000000         1899.400000          221.300000
# ...

# %%
# Selecting and Filtering the data

citi_bike_data = pd.read_csv('/content/drive/MyDrive/datasets/citibike_tripdata.csv')
citi_bike_data.shape
# Out:
# (32428, 10)

# %%
citi_bike_data.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
#
#                        name_localizedValue    usertype
# 0                        Annual Membership  Subscriber
# ...

# %%
citi_bike_data['tripduration']
# Out:
# 0         338
# 1        1482
# 2         232
# 3         190
# 4         303
#          ...
# 32423     396
# 32424     313
# 32425     316
# 32426    1130
# 32427     369
# Name: tripduration, Length: 32428, dtype: int64

# %%
citi_bike_data[['tripduration', 'starttime', 'stoptime']]
# Out:
#        tripduration            starttime             stoptime
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
# [32428 rows x 3 columns]

# %%
#df.loc[]
#df.iloc[]

# %%
# citi_bike_data[0]

# %%
citi_bike_data.loc[0]
# Out:
# tripduration                           338
# starttime              2018-05-01 00:04:47
# stoptime               2018-05-01 00:10:25
# start station id                      3639
# start station name              Harborside
# end station id                        3199
# end station name              Newport Pkwy
# bikeid                               33558
# name_localizedValue      Annual Membership
# usertype                        Subscriber
# Name: 0, dtype: object

# %%
# We use loc when we know name or label of row or column index

citi_bike_data.loc[1:10]
# Out:
#     tripduration            starttime             stoptime  start station id  \
# 1           1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2            232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3            190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4            303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5            176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
# 6            577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
# 7            830  2018-05-01 05:11:50  2018-05-01 05:25:41              3207
# 8            395  2018-05-01 05:12:07  2018-05-01 05:18:42              3225
# 9            170  2018-05-01 05:13:52  2018-05-01 05:16:43              3206
# 10           353  2018-05-01 05:18:36  2018-05-01 05:24:29              3225
#
#        start station name  end station id end station name  bikeid  \
# ...

# %%
# We use .loc when we use the built-in row or columns index
citi_bike_data.iloc[1:10]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5           176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
# 6           577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
# 7           830  2018-05-01 05:11:50  2018-05-01 05:25:41              3207
# 8           395  2018-05-01 05:12:07  2018-05-01 05:18:42              3225
# 9           170  2018-05-01 05:13:52  2018-05-01 05:16:43              3206
#
#       start station name  end station id end station name  bikeid  \
# 1               Grand St            3185        City Hall   33593
# 2        McGinley Square            3193     Lincoln Park   29217
# ...

# %%
new_citi_bike_data= citi_bike_data.head(10)
new_citi_bike_data
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5           176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
# 6           577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
# 7           830  2018-05-01 05:11:50  2018-05-01 05:25:41              3207
# 8           395  2018-05-01 05:12:07  2018-05-01 05:18:42              3225
# 9           170  2018-05-01 05:13:52  2018-05-01 05:16:43              3206
#
#       start station name  end station id end station name  bikeid  \
# ...

# %%
new_citi_bike_data.index = ['ride_'+str(i) for i in range(1, 11)]
new_citi_bike_data
# Out:
#          tripduration            starttime             stoptime  \
# ride_1            338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_2           1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3            232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_4            190  2018-05-01 02:03:29  2018-05-01 02:06:40
# ride_5            303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_6            176  2018-05-01 04:37:05  2018-05-01 04:40:01
# ride_7            577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ride_8            830  2018-05-01 05:11:50  2018-05-01 05:25:41
# ride_9            395  2018-05-01 05:12:07  2018-05-01 05:18:42
# ride_10           170  2018-05-01 05:13:52  2018-05-01 05:16:43
#
#          start station id     start station name  end station id  \
# ride_1               3639             Harborside            3199
# ride_2               3681               Grand St            3185
# ...

# %%
citi_bike_data
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
new_citi_bike_data.loc['ride_1']
# Out:
# tripduration                           338
# starttime              2018-05-01 00:04:47
# stoptime               2018-05-01 00:10:25
# start station id                      3639
# start station name              Harborside
# end station id                        3199
# end station name              Newport Pkwy
# bikeid                               33558
# name_localizedValue      Annual Membership
# usertype                        Subscriber
# Name: ride_1, dtype: object

# %%
new_citi_bike_data.loc['ride_1':'ride_5']
# Out:
#         tripduration            starttime             stoptime  \
# ride_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# ride_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#         start station id start station name  end station id end station name  \
# ride_1              3639         Harborside            3199     Newport Pkwy
# ride_2              3681           Grand St            3185        City Hall
# ride_3              3194    McGinley Square            3193     Lincoln Park
# ride_4              3185          City Hall            3186    Grove St PATH
# ride_5              3207        Oakland Ave            3195          Sip Ave
#
#         bikeid                      name_localizedValue    usertype
# ...

# %%
new_citi_bike_data.iloc[0]
# Out:
# tripduration                           338
# starttime              2018-05-01 00:04:47
# stoptime               2018-05-01 00:10:25
# start station id                      3639
# start station name              Harborside
# end station id                        3199
# end station name              Newport Pkwy
# bikeid                               33558
# name_localizedValue      Annual Membership
# usertype                        Subscriber
# Name: ride_1, dtype: object

# %%
new_citi_bike_data.iloc[0:5]
# Out:
#         tripduration            starttime             stoptime  \
# ride_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# ride_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#         start station id start station name  end station id end station name  \
# ride_1              3639         Harborside            3199     Newport Pkwy
# ride_2              3681           Grand St            3185        City Hall
# ride_3              3194    McGinley Square            3193     Lincoln Park
# ride_4              3185          City Hall            3186    Grove St PATH
# ride_5              3207        Oakland Ave            3195          Sip Ave
#
#         bikeid                      name_localizedValue    usertype
# ...

# %%
new_citi_bike_data.loc[::, 'tripduration':'bikeid']
# Out:
#          tripduration            starttime             stoptime  \
# ride_1            338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_2           1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3            232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_4            190  2018-05-01 02:03:29  2018-05-01 02:06:40
# ride_5            303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_6            176  2018-05-01 04:37:05  2018-05-01 04:40:01
# ride_7            577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ride_8            830  2018-05-01 05:11:50  2018-05-01 05:25:41
# ride_9            395  2018-05-01 05:12:07  2018-05-01 05:18:42
# ride_10           170  2018-05-01 05:13:52  2018-05-01 05:16:43
#
#          start station id     start station name  end station id  \
# ride_1               3639             Harborside            3199
# ride_2               3681               Grand St            3185
# ...

# %%
new_citi_bike_data.loc[::, ::]
# Out:
#          tripduration            starttime             stoptime  \
# ride_1            338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_2           1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3            232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_4            190  2018-05-01 02:03:29  2018-05-01 02:06:40
# ride_5            303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_6            176  2018-05-01 04:37:05  2018-05-01 04:40:01
# ride_7            577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ride_8            830  2018-05-01 05:11:50  2018-05-01 05:25:41
# ride_9            395  2018-05-01 05:12:07  2018-05-01 05:18:42
# ride_10           170  2018-05-01 05:13:52  2018-05-01 05:16:43
#
#          start station id     start station name  end station id  \
# ride_1               3639             Harborside            3199
# ride_2               3681               Grand St            3185
# ...

# %%
new_citi_bike_data.loc[::, ::2]
# Out:
#          tripduration             stoptime     start station name  \
# ride_1            338  2018-05-01 00:10:25             Harborside
# ride_2           1482  2018-05-01 01:55:53               Grand St
# ride_3            232  2018-05-01 01:35:22        McGinley Square
# ride_4            190  2018-05-01 02:06:40              City Hall
# ride_5            303  2018-05-01 04:32:16            Oakland Ave
# ride_6            176  2018-05-01 04:40:01        McGinley Square
# ride_7            577  2018-05-01 05:15:23  Baldwin at Montgomery
# ride_8            830  2018-05-01 05:25:41            Oakland Ave
# ride_9            395  2018-05-01 05:18:42  Baldwin at Montgomery
# ride_10           170  2018-05-01 05:16:43                Hilltop
#
#         end station name                      name_localizedValue
# ride_1      Newport Pkwy                        Annual Membership
# ride_2         City Hall                                  24 Hour
# ...

# %%
new_citi_bike_data.loc[::2, ::2]
# Out:
#         tripduration             stoptime     start station name  \
# ride_1           338  2018-05-01 00:10:25             Harborside
# ride_3           232  2018-05-01 01:35:22        McGinley Square
# ride_5           303  2018-05-01 04:32:16            Oakland Ave
# ride_7           577  2018-05-01 05:15:23  Baldwin at Montgomery
# ride_9           395  2018-05-01 05:18:42  Baldwin at Montgomery
#
#        end station name                      name_localizedValue
# ride_1     Newport Pkwy                        Annual Membership
# ride_3     Lincoln Park  FREE Bonus Month with Annual Membership
# ride_5          Sip Ave                        Annual Membership
# ride_7    Grove St PATH     Annual Membership from Citi Bike App
# ride_9    Grove St PATH                        Annual Membership

# %%
new_citi_bike_data.iloc[2:10:2, :8]
# Out:
#         tripduration            starttime             stoptime  \
# ride_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_7           577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ride_9           395  2018-05-01 05:12:07  2018-05-01 05:18:42
#
#         start station id     start station name  end station id  \
# ride_3              3194        McGinley Square            3193
# ride_5              3207            Oakland Ave            3195
# ride_7              3225  Baldwin at Montgomery            3186
# ride_9              3225  Baldwin at Montgomery            3186
#
#        end station name  bikeid
# ride_3     Lincoln Park   29217
# ride_5          Sip Ave   15271
# ride_7    Grove St PATH   33619
# ride_9    Grove St PATH   26300

# %%
new_citi_bike_data.loc[::,['start station name']]
# Out:
#             start station name
# ride_1              Harborside
# ride_2                Grand St
# ride_3         McGinley Square
# ride_4               City Hall
# ride_5             Oakland Ave
# ride_6         McGinley Square
# ride_7   Baldwin at Montgomery
# ride_8             Oakland Ave
# ride_9   Baldwin at Montgomery
# ride_10                Hilltop

# %%
new_citi_bike_data.loc[::,['start station name', 'starttime', 'bikeid']]
# Out:
#             start station name            starttime  bikeid
# ride_1              Harborside  2018-05-01 00:04:47   33558
# ride_2                Grand St  2018-05-01 01:31:10   33593
# ride_3         McGinley Square  2018-05-01 01:31:29   29217
# ride_4               City Hall  2018-05-01 02:03:29   29662
# ride_5             Oakland Ave  2018-05-01 04:27:12   15271
# ride_6         McGinley Square  2018-05-01 04:37:05   29298
# ride_7   Baldwin at Montgomery  2018-05-01 05:05:46   33619
# ride_8             Oakland Ave  2018-05-01 05:11:50   33624
# ride_9   Baldwin at Montgomery  2018-05-01 05:12:07   26300
# ride_10                Hilltop  2018-05-01 05:13:52   33555

# %%
# We want same columns values for ride_3 and ride_5
new_citi_bike_data.loc[['ride_3', 'ride_5'],['start station name', 'starttime', 'bikeid']]
# Out:
#        start station name            starttime  bikeid
# ride_3    McGinley Square  2018-05-01 01:31:29   29217
# ride_5        Oakland Ave  2018-05-01 04:27:12   15271

# %%
new_citi_bike_data.iloc[[2, 4], [1, 2, 0]]
# Out:
#                   starttime             stoptime  tripduration
# ride_3  2018-05-01 01:31:29  2018-05-01 01:35:22           232
# ride_5  2018-05-01 04:27:12  2018-05-01 04:32:16           303

# %%
arr1 = np.random.randint(10, 20, 5)
arr1
# Out:
# array([17, 12, 10, 13, 15])

# %%
arr1 > 15
# Out:
# array([ True, False, False, False, False])

# %%
arr1[arr1 > 15]
# Out:
# array([17])

# %%
# Conditional Indexing
new_citi_bike_data[new_citi_bike_data['tripduration']>200]
# Out:
#         tripduration            starttime             stoptime  \
# ride_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_7           577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ride_8           830  2018-05-01 05:11:50  2018-05-01 05:25:41
# ride_9           395  2018-05-01 05:12:07  2018-05-01 05:18:42
#
#         start station id     start station name  end station id  \
# ride_1              3639             Harborside            3199
# ride_2              3681               Grand St            3185
# ride_3              3194        McGinley Square            3193
# ride_5              3207            Oakland Ave            3195
# ride_7              3225  Baldwin at Montgomery            3186
# ride_8              3207            Oakland Ave            3185
# ...

# %%
# In our original datafrmae, we want to access all the trips where start station name is Grand St
citi_bike_data[citi_bike_data['start station name'] == 'Grand St']
# Out:
#        tripduration            starttime             stoptime  \
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 104             125  2018-05-01 07:23:51  2018-05-01 07:25:57
# 276             171  2018-05-01 08:35:39  2018-05-01 08:38:30
# 381           25958  2018-05-01 09:29:09  2018-05-01 16:41:48
# 400             228  2018-05-01 09:56:13  2018-05-01 10:00:01
# ...             ...                  ...                  ...
# 32057           612  2018-05-30 08:27:06  2018-05-30 08:37:19
# 32180           263  2018-05-30 09:14:22  2018-05-30 09:18:46
# 32238           247  2018-05-30 10:00:17  2018-05-30 10:04:25
# 32246           227  2018-05-30 10:08:49  2018-05-30 10:12:36
# 32261           112  2018-05-30 10:28:25  2018-05-30 10:30:18
#
#        start station id start station name  end station id  \
# 1                  3681           Grand St            3185
# 104                3681           Grand St            3275
# ...

# %%
# Access the trip data for first 8 columns for all the rides where tripduration is more than 200

new_citi_bike_data[new_citi_bike_data['tripduration']>200].iloc[::, :8]
# Out:
#         tripduration            starttime             stoptime  \
# ride_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_7           577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ride_8           830  2018-05-01 05:11:50  2018-05-01 05:25:41
# ride_9           395  2018-05-01 05:12:07  2018-05-01 05:18:42
#
#         start station id     start station name  end station id  \
# ride_1              3639             Harborside            3199
# ride_2              3681               Grand St            3185
# ride_3              3194        McGinley Square            3193
# ride_5              3207            Oakland Ave            3195
# ride_7              3225  Baldwin at Montgomery            3186
# ride_8              3207            Oakland Ave            3185
# ...

# %%
new_citi_bike_data.loc[new_citi_bike_data['tripduration']>200, 'tripduration':'bikeid']
# Out:
#         tripduration            starttime             stoptime  \
# ride_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_7           577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ride_8           830  2018-05-01 05:11:50  2018-05-01 05:25:41
# ride_9           395  2018-05-01 05:12:07  2018-05-01 05:18:42
#
#         start station id     start station name  end station id  \
# ride_1              3639             Harborside            3199
# ride_2              3681               Grand St            3185
# ride_3              3194        McGinley Square            3193
# ride_5              3207            Oakland Ave            3195
# ride_7              3225  Baldwin at Montgomery            3186
# ride_8              3207            Oakland Ave            3185
# ...
